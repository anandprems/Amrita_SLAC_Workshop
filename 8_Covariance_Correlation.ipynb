# %% [markdown]
# Covariance and correlation are two significantly used terms in the field of statistics and probability theory. Both the terms measure the relationship and the dependency between two variables

# %%
#importing librabries
from numpy import mean
from numpy import std
from numpy.random import randn
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('correlation.png') 
plt.imshow(img)

# %%
d1 = 20 * randn(1000) + 100
#print(d1)

# %%
d2 = d1 + (10 * randn(1000) + 50)
#print(d2)

# %%
print('mean and SD of d1', mean(d1), std(d1))
# Out:
# mean and SD of d1 100.05264654821745 20.17955463201553

# %%
print('mean and SD of d2', mean(d2), std(d2))
# Out:
# mean and SD of d2 150.29850904293065 22.758198141511144

# %%
plt.scatter(d1,d2)

# %%
#covariance
covariance = np.cov(d1, d2)
print(covariance)
# Out:
# [[405.86234814 400.43213662]
#  [400.43213662 497.10418003]]

# %%
#Pearson’s Correlation
from scipy.stats import pearsonr
corr, _ = pearsonr(d1, d2)
print('Pearsons correlation:', corr)
# Out:
# Pearsons correlation: 0.8914886844221452

# %%
#Spearman’s Correlation
from scipy.stats import spearmanr
corr1, _ = spearmanr(d1, d2)
print('Spearmans correlation:', corr1)
# Out:
# Spearmans correlation: 0.8812567372567373
